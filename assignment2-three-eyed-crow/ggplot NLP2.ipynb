# %%
#from ggplot import ggplot, geom_line, aes, theme, element_text, ylab, xlab
from ggplot import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /Users/disheng/anaconda3/lib/python3.6/site-packages/ggplot/utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# /Users/disheng/anaconda3/lib/python3.6/site-packages/ggplot/stats/smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp
# /Users/disheng/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
Window1 = [0.29419592, 0.38058575, 0.42651632390460403, 0.4463985265356283, 0.4581894491269667, 0.4669186703986551]
Window2 = [0.3592815066056661, 0.4705133155811951, 0.5005257143748718, 0.5178314, 0.545594288752526, 0.556333]
Window3 = [0.363658002, 0.4676716758187874, 0.5006393076, 0.5240, 0.54152, 0.54835094]
dependency = [0.21222, 0.2806016959798612, 0.3052093251013487, 0.3234283118326496, 0.33636569368330943, 0.33838879766896224]

# %%
df = pd.DataFrame({'Window1': Window1, 'Window2': Window2, 'Window3': Window3, 'Dependency': dependency})
df['x'] = df.index + 1
test = ggplot(aes(x='x'), data=df) +\
    geom_line(aes(y='Window1'), color='blue') +\
    geom_line(aes(y='Window2'), color='red') +\
    geom_line(aes(y='Window3'), color='purple') +\
    geom_line(aes(y='Dependency'), color='green') +\
    xlab(element_text(size=20, text='Epochs')) + ylab(element_text(size=20, text='Dependency')) +\
    theme(axis_text=element_text(size=20), x_axis_text=element_text(size=20))
# Out:
#   File "<ipython-input-84-d70f1530589e>", line 3
#     test = ggplot(aes(x='x'), data=df) +    geom_line(aes(y='Window1'), color='blue') +    geom_line(aes(y='Window2'), color='red') +    geom_line(aes(y='Window3'), color='purple') +    geom_line(aes(y='Dependency'), color='green') +    xlab(element_text(size=20, text='Epochs')) + ylab(element_text(size=20, text='Dependency')) +    theme(axis_text=element_text(size=20), x_axis_text=element_text(size=20))+    scale_color_brewer(type='div', palette=7) +
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ^
# SyntaxError: invalid syntax

# %%
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Set1')

# %%
num=0
for column in df.drop('x', axis=1):
    num+=1
    plt.plot(df['x'], df[column], marker='+', color=palette(num), linewidth=1, alpha=0.9, label=column)

# %%
plt.legend(loc=2)

# %%
#plt.title("Dif", loc='left', fontsize=12, fontweight=0, color='orange')
plt.xlabel("Epoch")
plt.ylabel("Evaluation result on Dev.")
plt.grid(False)

# %%
plt.show()

# %%
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Set1')

# %%
d50 = [0.242, 0.338, 0.4297, 0.4608, 0.46972406214104095,0.48841491551]
d200 = [0.3592815066056661, 0.4705133155811951, 0.5005257143748718, 0.5178314, 0.545594288752526, 0.556333]
d300 = [0.39251693,0.485718549,0.5129931837248801,0.5241240307204864,0.557679715003, 0.56394177]

# %%
df2 = pd.DataFrame({'d50': d50, 'd200': d200, 'd300': d300})
df2['x'] = df.index + 1

# %%
df2['d200']
# Out:
# 0    0.359282
# 1    0.470513
# 2    0.500526
# 3    0.517831
# 4    0.545594
# 5    0.556333
# Name: d200, dtype: float64

# %%
num=0
for column in df2.drop('x', axis=1):
    num+=1
    #print (df[column])
    plt.plot(df2['x'], df2[column], marker='+', color=palette(num), linewidth=1, alpha=0.9, label=column)

# %%
plt.xlabel("Epoch")
plt.ylabel("Evaluation result on Dev.")
plt.grid(False)
plt.legend(loc=2)

# %%
plt.show()

# %%
D1_8M = [0.35944696882877486,0.505964244817569,0.5338583383589725,0.5624815296600757,0.5734916560724576 ,0.5690286774939987]
D1M = [0.39251693, 0.485718549,0.5129931837248801,0.5241240307204864,0.55767971500,0.563941]
D2_7M = [0.3717386431274768, 0.4982780948707378, 0.52333614135471, 0.545,0.565, 0.5734942478137923]

# %%
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Set1')

# %%
df3 = pd.DataFrame({'1M': D1M, '1.8M': D1_8M, '2.7M': D2_7M})
df3['x'] = df3.index + 1

# %%
num=0
for column in df3.drop('x', axis=1):
    num+=1
    #print (df[column])
    plt.plot(df3['x'], df3[column], marker='+', color=palette(num), linewidth=1, alpha=0.9, label=column)

# %%
plt.xlabel("Epoch")
plt.ylabel("Evaluation result on Dev.")
plt.grid(False)
plt.legend(loc=2)
# Out:
# No handles with labels found to put in legend.

# %%
plt.show()

# %%
batch1ins =  np.load('plot_Data/mlp_dot_1batch_ins_1.npy')
#batch2ins =  np.load('plot_Data/mlp_dot_5batch_ins_2.npy')
batch5ins =  np.load('plot_Data/mlp_dot_5batch_ins_1.npy')
batch10ins =  np.load('plot_Data/mlp_dot_10batch_ins_1.npy')
batch20ins =  np.load('plot_Data/mlp_dot_20batch_int_1.npy')
batch50ins =  np.load('plot_Data/mlp_dot_50batch_ins_1.npy')
batch100ins = np.load('plot_Data/mlp_dot_100batch_ins_1.npy')

# %%
batch1ins[50], batch5ins[50], batch10ins[50],  batch50ins[50], batch100ins[50]
# Out:
# (0.3689795918367347,
#  0.46775510204081633,
#  0.33387755102040817,
#  0.35591836734693877,
#  0.2653061224489796)

# %%
#len(batch20ins)
#len(batch10ins)
print(batch20ins)
# Out:
# []

# %%
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Set1')

# %%
df2 = pd.DataFrame({'1': batch1ins, '5': batch5ins, '50': batch50ins, '100': batch100ins})
df2['x'] = df2.index + 1

# %%
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(dpi=200)
plt.xlabel("Epoch")
#plt.title("Batch size influence on instruction evaluation result")
plt.ylabel("Accracy on Dev Data")
plt.grid(False)
num=0
for column in df2.drop('x', axis=1):
    num+=1
    #print (df[column])
    plt.plot(df2['x'], df2[column], marker='+', color=palette(num), linewidth=1, alpha=0.9, label=column)
plt.legend(loc=2)

# %%
df2.drop('x', axis=1)
# Out:
#            1        10       100         5        50
# 0   0.154286  0.032653  0.023673  0.075102  0.031020
# 1   0.164082  0.088980  0.034286  0.120000  0.038367
# 2   0.160816  0.104490  0.037551  0.161633  0.039184
# 3   0.167347  0.142041  0.044898  0.164082  0.031837
# 4   0.173061  0.155918  0.040000  0.182857  0.055510
# 5   0.183673  0.169796  0.043265  0.187755  0.082449
# 6   0.181224  0.164082  0.044898  0.188571  0.097959
# 7   0.177143  0.172245  0.047347  0.188571  0.104490
# 8   0.183673  0.182857  0.064490  0.204898  0.115102
# 9   0.180408  0.188571  0.060408  0.199184  0.123265
# 10  0.176327  0.191837  0.068571  0.217959  0.132245
# 11  0.182041  0.199184  0.090612  0.258776  0.145306
# 12  0.188571  0.191837  0.083265  0.297959  0.150204
# 13  0.183673  0.193469  0.104490  0.313469  0.148571
# 14  0.187755  0.199184  0.118367  0.320816  0.157551
# 15  0.187755  0.204898  0.115918  0.363265  0.152653
# 16  0.181224  0.231837  0.128163  0.360000  0.160816
# ...

# %%
plt.show()

# %%
batch1int = np.load('plot_Data/mlp_dot_1batch_int_1.npy')
batch5int =  np.load('plot_Data/mlp_dot_5batch_int_1.npy')
batch10int =  np.load('plot_Data/mlp_dot_10batch_int_1.npy')
batch20int =  np.load('plot_Data/mlp_dot_20batch_int_1.npy')
batch50int = np.load('plot_Data/mlp_dot_50batch_int_1.npy')
batch100int =  np.load('plot_Data/mlp_dot_100batch_int_1.npy')

# %%
batch1int[50], batch5int[50], batch10int[50],  batch50int[50], batch100int[50]
# Out:
# (0.1306122448979592,
#  0.23265306122448978,
#  0.09387755102040816,
#  0.07346938775510205,
#  0.0326530612244898)

# %%
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Set1')

# %%
df2 = pd.DataFrame({'1': batch1int, '5': batch5int, '10': batch10int,   '50': batch50int, '100': batch100int})
df2['x'] = df2.index + 1

# %%
plt.figure(dpi=200)
plt.xlabel("Epoch")
#plt.title("Batch size influence on interaction evaluation result")
plt.ylabel("Accracy on Dev Data")
plt.grid(False)
num=0
for column in df2.drop('x', axis=1):
    num+=1
    #print (df[column])
    plt.plot(df2['x'], df2[column], marker='+', color=palette(num), linewidth=1, alpha=0.9, label=column)
plt.legend(loc=2)

# %%
#interaction
onehot = np.load('plot_Data/one_hot_5batch_int_sim_1.npy')
dotdot = np.load('plot_Data/dot_dot_5batch_int_sim_1.npy')
dotmlp = np.load('plot_Data/dot_mlp_5batch_int_sim_1.npy')
mlpdot = np.load('plot_Data/mlp_dot_5batch_int_1.npy')
mlpmlp = np.load('plot_Data/mlp_mlp_5batch_int_sim_1.npy')

# %%
onehot[50], dotdot[50], dotmlp[51],  mlpdot[50], mlpmlp[50]
# Out:
# (0.12244897959183673,
#  0.00816326530612245,
#  0.00816326530612245,
#  0.23265306122448978,
#  0.2571428571428571)

# %%
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Set1')
df2 = pd.DataFrame({'one hot/dot': onehot, 'dot/dot': dotdot, 'dot/mlp': dotmlp,   'mlp/dot': mlpdot, 'mlp/mlp': mlpmlp})
df2['x'] = df2.index + 1

# %%
plt.figure(dpi=200)
plt.xlabel("Epoch")
#plt.title("State embedding method influence on interaction evaluation result")
plt.ylabel("Accracy on Dev Data")
plt.grid(False)
num=-1
for column in df2.drop('x', axis=1):
    num+=1
    #print (df[column])
    plt.plot(df2['x'], df2[column], marker='.', color=palette(num), linewidth=0.5, alpha=0.7, label=column)
plt.legend(loc=2)

# %%
#instruction
onehot = np.load('plot_Data/one_hot_5batch_ins_sim_1.npy')
dotdot = np.load('plot_Data/dot_dot_5batch_ins_sim_1.npy')
dotmlp = np.load('plot_Data/dot_mlp_5batch_ins_sim_1.npy')
mlpdot = np.load('plot_Data/mlp_dot_5batch_ins_1.npy')
mlpmlp = np.load('plot_Data/mlp_mlp_5batch_ins_sim_1.npy')

# %%
onehot[50], dotdot[50], dotmlp[50],  mlpdot[50], mlpmlp[50]
# Out:
# (0.3787755102040816,
#  0.1763265306122449,
#  0.16489795918367348,
#  0.46775510204081633,
#  0.49142857142857144)

# %%
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Set1')
df2 = pd.DataFrame({'one hot/dot': onehot, 'dot/dot': dotdot, 'dot/mlp': dotmlp,   'mlp/dot': mlpdot, 'mlp/mlp': mlpmlp})
df2['x'] = df2.index + 1

# %%
plt.figure(dpi=200)
plt.xlabel("Epoch")
#plt.title("State embedding method influence on interaction evaluation result")
plt.ylabel("Accracy on Dev Data")
plt.grid(False)
num=-1
for column in df2.drop('x', axis=1):
    num+=1
    #print (df[column])
    plt.plot(df2['x'], df2[column], marker='.', color=palette(num), linewidth=0.5, alpha=0.7, label=column)
plt.legend(loc=2)

# %%
#interaction
RMS = np.load('plot_Data/mlp_dot_5batch_int_RMS_1.npy')
adam = np.load('plot_Data/mlp_dot_5batch_int_adam_1.npy')
golo = np.load('plot_Data/mlp_dot_5batch_int_2_golo.npy')
simpleSGD = np.load('plot_Data/mlp_dot_5batch_int_1.npy')

# %%
RMS[50], adam[50], simpleSGD[50]
# Out:
# (0.19183673469387755, 0.2938775510204082, 0.23265306122448978)

# %%
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Set1')
df2 = pd.DataFrame({'RMS': RMS, 'adam': adam, 'simpleSGD': simpleSGD})
df2['x'] = df2.index + 1

# %%
plt.figure(dpi=200)
plt.xlabel("Epoch")
#plt.title("State embedding method influence on interaction evaluation result")
plt.ylabel("Accracy on Dev Data")
plt.grid(False)
num=-0
for column in df2.drop('x', axis=1):
    num+=2
    #print (df[column])
    plt.plot(df2['x'], df2[column], marker='.', color=palette(num), linewidth=0.5, alpha=0.7, label=column)
plt.legend(loc=4)

# %%
#instruction
RMS = np.load('plot_Data/mlp_dot_5batch_ins_RMS_1.npy')
adam = np.load('plot_Data/mlp_dot_5batch_ins_adam_1.npy')
simpleSGD = np.load('plot_Data/mlp_dot_5batch_ins_1.npy')

# %%
RMS[50], adam[50], simpleSGD[50]
# Out:
# (0.47183673469387755, 0.5551020408163265, 0.46775510204081633)

# %%
#Builder:
LSTM = np.load('plot_Data2/mlp_dot_5batch_int_1_LSTM.npy')
golo = np.load('plot_Data2/mlp_dot_5batch_int_2_golo.npy')
gru = np.load('plot_Data2/mlp_dot_5batch_int_sim_1_gru.npy')

# %%
LSTM[50], golo[50], gru[50]
# Out:
# (0.24081632653061225, 0.22857142857142856, 0.17142857142857143)

# %%
#Builder Ins
LSTM = np.load('plot_Data2/mlp_dot_5batch_ins_1_LSTM.npy')
golo = np.load('plot_Data2/mlp_dot_5batch_ins_2_golo.npy')
gru = np.load('plot_Data2/mlp_dot_5batch_ins_sim_1_gru.npy')

# %%
LSTM[50], golo[50], gru[50]
# Out:
# (0.5044897959183674, 0.4742857142857143, 0.446530612244898)

# %%
#parameters
Nohistory = np.load('plot_Data2/mlp_dot_5batch_int_sim_1_nohis.npy')
Nostate = np.load('plot_Data2/mlp_dot_5batch_int_sim_1_nostate.npy')
Noattention =  np.load('plot_Data2/mlp_dot_5batch_int_sim_1_noattenins.npy')

# %%
Nohistory[50], Nostate[51], Noattention[50]
# Out:
# (0.23673469387755103, 0.004081632653061225, 0.2163265306122449)

# %%
#parameters
Nohistory = np.load('plot_Data2/mlp_dot_5batch_ins_sim_1_nohis.npy')
Nostate = np.load('plot_Data2/mlp_dot_5batch_ins_sim_1_nostate.npy')
Noattention =  np.load('plot_Data2/mlp_dot_5batch_ins_sim_1_noattenins.npy')

# %%
Nohistory[50], Nostate[51], Noattention[50]
# Out:
# (0.4881632653061225, 0.15755102040816327, 0.4742857142857143)

# %%
#from ggplot import ggplot, geom_line, aes, theme, element_text, ylab, xlab
from ggplot import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
VirusMessage = [11.34, 4.43, 0.21, 1.64, 0.37, 1.34, 0.05, 0.16] 
Cryptomining = [27.05, 22.65, 1.05, 8.2, 1.9, 1.75, 0.25, 0.8]

# %%
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Set1')
df2 = pd.DataFrame({'Virus Message': VirusMessage, 'Crypto Mining': Cryptomining})
df2['x'] = df2.index + 1

# %%
plt.figure(dpi=200)
plt.xlabel("Zones")
#plt.title("State embedding method influence on interaction evaluation result")
plt.ylabel("Average number in past 6 months")
my_xticks = ["Africa", "APAC", "COPEC", "Europe", "Global", "LAS", "Mexico","NAZ"]
plt.xticks(df2['x'], my_xticks)
plt.grid(False)
num=-0
for column in df2.drop('x', axis=1):
    num+=2
    #print (df[column])
    plt.plot(df2['x'], df2[column], marker='.', color=palette(num-3), linewidth=0.5, alpha=0.7, label=column)
plt.legend(loc=1)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-208e07b1e443> in <module>()
# ----> 1 plt.clear
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'clear'

# %%
#from ggplot import ggplot, geom_line, aes, theme, element_text, ylab, xlab
from ggplot import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
VirusMessage = [111.0697674,113.3114754,22.94117647, 45.09965636,52.88074534, 2.349367089,17.3364486, 2.98838897] 
Spamemail = [166.9767442, 74.75409836, 22.94117647, 98.35051546, 114.0931677, 18.4556962, 17.3364486, 30.32656023]

# %%
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Set1')
df2 = pd.DataFrame({'Virus Message': VirusMessage, 'Spam EMail': Spamemail})
df2['x'] = df2.index + 1

# %%
plt.figure(dpi=200)
plt.xlabel("Positions")
#plt.title("State embedding method influence on interaction evaluation result")
plt.ylabel("Average number in past 6 months")
my_xticks = ["VP","IT","Finance", "Director", "Manager","Staff","Vendor","Blue Collar"]
plt.xticks(df2['x'], my_xticks[::-1])
plt.grid(False)
num=0
for column in df2.drop('x', axis=1):
    num+=2
    #print (df[column])
    plt.plot(df2['x'][::-1], df2[column], marker='.', color=palette(num-3), linewidth=0.5, alpha=0.7, label=column)
plt.legend(loc=2)

# %%
import numpy as np
import matplotlib.pyplot as plt


data = [[ 111.0697674,113.3114754,22.94117647, 45.09965636,52.88074534, 2.349367089,17.3364486, 2.98838897],
        [ 166.9767442, 74.75409836, 22.94117647, 98.35051546, 114.0931677, 18.4556962, 17.3364486, 30.32656023]]

columns = ("VP","IT","Finance", "Director", "Manager","Staff","Vendor","Blue Collar")
rows = ['Virus message','Spam Email']

values = np.arange(0, 300, 25)
value_increment = 50

# Get some pastel shades for the colors
colors = plt.cm.BuPu(np.linspace(0, 0.5, len(rows)))
n_rows = len(data)

index = np.arange(len(columns)) + 0.3
bar_width = 0.4

# Initialize the vertical-offset for the stacked bar chart.
y_offset = np.zeros(len(columns))

# Plot bars and create text labels for the table
cell_text = []
for row in range(n_rows):
    plt.bar(index, data[row], bar_width, bottom=y_offset, color=colors[row])
    y_offset = y_offset + data[row]
    cell_text.append(['%1.1f' % (x) for x in y_offset])
# Reverse colors and text labels to display the last value at the top.
colors = colors[::-1]
cell_text.reverse()

# Add a table at the bottom of the axes
the_table = plt.table(cellText=cell_text,
                      rowLabels=rows,
                      rowColours=colors,
                      colLabels=columns,
                      loc='bottom')

# Adjust layout to make room for the table:
plt.subplots_adjust(left=0.2, bottom=0.2)

plt.ylabel("Loss in ${0}'s".format(value_increment))
plt.yticks(values * value_increment, ['%d' % val for val in values])
plt.xticks([])
plt.title('Loss by Disaster')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 7
menMeans = (111.0697674,113.3114754,40, 45.09965636,52.88074534, 2.349367089, 2.98838897)[::-1]
womenMeans = (166.9767442, 74.75409836, 40, 98.35051546, 114.0931677, 18.4556962,30.32656023)[::-1]
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, color='b')
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, color='r')

plt.ylabel('Average numbr in the past 6 months')
plt.xticks(ind, ("Executive","IT","Sensitive", "Director", "Manager","Staff","Blue Collar")[::-1])
plt.yticks(np.arange(0, 300, 50))
plt.legend((p1[0], p2[0]), ('Virus Message', 'Spam Email'))
plt.savefig('position.png', dpi = 300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 8
menMeans = (11.34, 4.43, 0.21, 1.64, 0.37, 1.34, 0.05, 0.16)
womenMeans = (27.05, 22.65, 1.05, 8.2, 1.9, 1.75, 0.25, 0.8)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, color='b')
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, color='r')

plt.ylabel('Average numbr in the past 6 months')
plt.xticks(ind, ("Africa","APAC","COPEC", "Europe", "Global","LAS","Mexico","NAZ"))
plt.yticks(np.arange(0, 40, 5))
plt.legend((p1[0], p2[0]), ('Virus Message', 'Crypto Mining'))
plt.savefig('location.png', dpi = 300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 8
virusmessage = (11.34, 4.43, 0.21, 1.64, 0.37, 1.34, 0.05, 0.16)
crypto = (27.05, 22.65, 1.05, 8.2, 1.9, 1.75, 0.25, 0.8)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, virusmessage, width, color='b')
p2 = plt.bar(ind, crypto, width,
             bottom=menMeans, color='r')

plt.ylabel('Average numbr in the past 6 months')
plt.xticks(ind, ("Africa", "APAC", "COPEC", "Europe", "Global", "LAS", "Mexico","NAZ")
plt.yticks(np.arange(0, 40, 5))
plt.legend((p1[0], p2[0]), ('Virus Message', 'Crypto Mining'))
plt.savefig('Location.png', dpi = 300)
plt.show()
# Out:
#   File "<ipython-input-72-fa3ca893a809>", line 17
#     plt.yticks(np.arange(0, 40, 5))
#       ^
# SyntaxError: invalid syntax

# %%
import xlrd

workbook = xlrd.open_workbook("Predicted7.xlsx","rb")
sheets = workbook.sheet_names()
required_data = []
for sheet_name in sheets:
    sh = workbook.sheet_by_name(sheet_name)
    for rownum in range(sh.nrows):
        row_valaues = sh.row_values(rownum)
        required_data.append((row_valaues[0], row_valaues[1]))

# %%
real=[]
predicted =[]

# %%
for j, k in required_data[1:]:
    real.append(j)
    predicted.append(k)

# %%
predicted
# Out:
# [11.404626693053231,
#  26.914440639991437,
#  16.228892910585316,
#  16.228892910585316,
#  83.88424862676719,
#  51.87733076753366,
#  39.59384016082256,
#  51.52377965634151,
#  52.00605634642428,
#  83.49056560164449,
#  51.30816431733452,
#  51.636201708968485,
#  16.228892910585316,
#  120.0,
#  113.0,
#  26.032757703364556,
#  51.636201708968485,
#  83.8810987764482,
#  83.14450427381463,
#  64.46177497003251,
#  16.228892910585316,
#  34.56373489585724,
#  67.03587871929622,
#  109.0,
#  87.49514884017132,
#  51.87733076753366,
#  54.605105006442884,
#  83.14122439867415,
#  83.88045781546107,
#  83.14148934246478,
#  29.50886846207696,
#  29.50886846207696,
#  99.93402390832506,
#  83.1435541038491,
#  51.636201708968485,
#  100.8218604834608,
#  83.14148934246478,
#  51.87733076753366,
#  83.49099546784325,
#  83.14122439867415,
#  51.87733076753366,
#  83.8808332652305,
#  51.636201708968485,
#  83.14180910524765,
#  51.52377965634151,
#  100.8218604834608,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 120
menMeans = real[::-1]
womenMeans = predicted[::-1]
ind = np.arange(N)    # the x locations for the groups
      # the width of the bars: can also be len(x) sequence

p1 = plt.scatter(ind, menMeans, color='b')
p2 = plt.scatter(ind, womenMeans, color='r')

plt.ylabel('Risk Behavior Score')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
plt.yticks(np.arange(0, 130, 30))
#plt.legend((p1, p2), ('Real Score', 'Predicted Score'))
plt.savefig('predicted.png', dpi = 300)
plt.show()

# %%
plt.savefig('position.png', dpi = 300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


plt.scatter(real, predicted, alpha=0.5)
plt.show()

# %%
len(real)
# Out:
# 206

# %%
menMeans
# Out:
# [5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  47.57239559,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  22.94804906,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  35.12264583,
#  35.12264583,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
#  5.092844367,
# ...
